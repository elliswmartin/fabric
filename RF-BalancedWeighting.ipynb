# %% [markdown]
# # Random Forest with Balanced Weighting - Scalar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
def rf_weighted_grid_search_cv(X, y, cv_folds=5):
    """
    Perform grid search cross-validation for Random Forest classifier on the given data.
    
    Parameters:
    - X: Features dataset.
    - y: Target variable dataset.
    - cv_folds: Number of folds for cross-validation.
    
    Returns:
    - grid_search: The fitted GridSearchCV object.
    """
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)
    
    # Define a pipeline with the classifier
    pipeline = Pipeline([
        ('rf', RandomForestClassifier(random_state=23, class_weight='balanced'))  # Random Forest classifier with adjusted class weighting
    ])
    
    param_grid = {
        'rf__n_estimators': [50, 150, 200],  # Number of trees in the forest
        'rf__max_features': ['sqrt', 'log2', None],  # The number of features to consider when looking for the best split
        'rf__max_depth': [None, 10, 20, 30],  # Maximum number of levels in each decision tree
        'rf__min_samples_split': [2, 5, 10],  # Minimum number of data points placed in a node before the node is split
        'rf__class_weight': ['balanced', 'balanced_subsample']  # Adjust weights inversely proportional to class frequencies
    }
    
    # Initialize GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid, cv=cv_folds, scoring='accuracy', verbose=3, n_jobs=-1)
    
    # Perform grid search cross-validation
    grid_search.fit(X_train, y_train)
    
    print("Best parameters found: ", grid_search.best_params_)
    print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
    
    # Optionally, evaluate on the test set
    test_score = grid_search.score(X_test, y_test)
    print("Test set score: {:.2f}".format(test_score))
    
    return grid_search

# %% [markdown]
# # Import training dataset

# %%
train_df_scalar = pd.read_pickle('/Users/erin/Documents/comp-viz/final-project/fabric/pkls/train_0406_scalar_non-aug.pkl')
train_df_scalar.head()
# Out:
#    label   category            0             1            2         3  \
# 0      0    Blended  3441.793288  2.028531e+07  1844.056770  0.150226
# 1      1      Denim  7211.992783  7.747671e+06  2271.840993  0.151475
# 2      2  Polyester  8856.756862  5.854463e+06  1967.259618  0.160454
# 3      0    Blended  7018.112788  7.817569e+06  1953.124972  0.152300
# 4      3     Cotton  7932.263905  6.971318e+06  2053.412469  0.157971
#
#             4         5         6         7  ...        22        23  \
# 0  346.120911  0.005210  0.000093  0.000063  ...  0.027344  0.054688
# 1  348.998260  0.004833 -0.000067  0.000038  ...  0.100000  0.048649
# 2  369.684998  0.002032 -0.000002  0.000008  ...  0.027778  0.004630
# 3  350.899200  0.004582  0.000011  0.000034  ...  0.052239  0.063433
# 4  363.965454  0.002823 -0.000003  0.000017  ...  0.030612  0.047619
#
#          24        25        26        27        28        29        30  \
# 0  0.035156  0.039062  0.031250  0.027344  0.046875  0.062500  0.050781
# 1  0.021622  0.024324  0.013514  0.021622  0.024324  0.043243  0.016216
# 2  0.004630  0.250000  0.129630  0.194444  0.018519  0.004630  0.027778
# 3  0.052239  0.007463  0.022388  0.044776  0.085821  0.074627  0.033582
# 4  0.054422  0.047619  0.051020  0.081633  0.013605  0.044218  0.047619
#
#          31
# 0  0.050781
# 1  0.070270
# 2  0.004630
# 3  0.029851
# 4  0.054422
#
# [5 rows x 34 columns]

# %% [markdown]
# # Run random forest model with equal balance on class weights using scalar features

# %%
X_sc = train_df_scalar.iloc[:,2:]
y_sc = train_df_scalar.iloc[:,0]

cv_params_scalar = rf_weighted_grid_search_cv(X_sc, y_sc)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.691 total time=   2.8s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.675 total time=   2.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.689 total time=   2.9s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.701 total time=   3.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.677 total time=   3.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.680 total time=   3.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.698 total time=   3.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.694 total time=   8.6s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.690 total time=   8.7s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.713 total time=   8.8s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.706 total time=   8.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.688 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.702 total time=   9.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.689 total time=   2.9s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.684 total time=   2.8s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.692 total time=  11.9s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.713 total time=  12.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.706 total time=  11.7s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.694 total time=  11.8s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.702 total time=  11.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.705 total time=   8.5s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.689 total time=   8.7s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.676 total time=   2.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.698 total time=   8.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.709 total time=   8.7s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.692 total time=   2.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.698 total time=   8.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.674 total time=   2.7s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.686 total time=   2.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.684 total time=   2.7s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.689 total time=  11.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.710 total time=  11.6s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.704 total time=  11.5s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.699 total time=  11.8s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.692 total time=   8.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.686 total time=   8.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.699 total time=   8.4s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.698 total time=  11.5s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.695 total time=   8.8s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.675 total time=   2.9s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.693 total time=   8.3s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.689 total time=   3.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.691 total time=   3.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.677 total time=   3.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.701 total time=   3.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.699 total time=  11.0s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.687 total time=  11.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.696 total time=  11.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time=  11.3s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.694 total time=  11.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.690 total time=   8.9s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.713 total time=   9.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.680 total time=   3.0s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.706 total time=   9.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.698 total time=   3.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.702 total time=   8.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.688 total time=   2.7s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.694 total time=   9.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.689 total time=   3.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.684 total time=   3.0s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.692 total time=  12.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.713 total time=  12.3s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.702 total time=  11.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.694 total time=  11.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.706 total time=  12.1s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.676 total time=   2.9s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.689 total time=   8.7s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.705 total time=   8.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.692 total time=   3.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.698 total time=   8.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.709 total time=   9.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.698 total time=   9.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.686 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.674 total time=   2.9s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.684 total time=   2.8s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.689 total time=  11.7s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.710 total time=  11.4s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.704 total time=  11.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.699 total time=  11.9s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.698 total time=  11.8s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.686 total time=   8.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.699 total time=   8.6s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.695 total time=   8.5s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.692 total time=   8.6s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.693 total time=   8.9s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.699 total time=  11.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.687 total time=  11.5s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.696 total time=  11.6s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time=  11.9s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.694 total time=  11.5s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.687 total time=  18.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.681 total time=  17.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.700 total time=  17.6s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.699 total time=  17.5s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.693 total time=  17.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.702 total time=  16.6s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.682 total time=  17.1s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.695 total time=  17.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.688 total time=  17.1s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.690 total time=  52.8s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.711 total time=  52.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.697 total time=  50.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.705 total time=  52.5s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.701 total time=  51.6s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.695 total time=  17.5s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.692 total time= 1.1min
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.713 total time= 1.1min
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.707 total time= 1.1min
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.699 total time= 1.1min
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.704 total time= 1.2min
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.675 total time=  16.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.699 total time=  16.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.687 total time=  50.7s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.709 total time=  51.6s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.702 total time=  50.3s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.699 total time=  50.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.692 total time=  50.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.694 total time=  16.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.689 total time=  16.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.684 total time=  16.9s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.685 total time= 1.1min
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.713 total time= 1.1min
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.703 total time= 1.1min
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.704 total time= 1.1min
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.622 total time=   2.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.624 total time=   2.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.643 total time=   2.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.699 total time= 1.1min
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.626 total time=   2.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.624 total time=   2.0s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.683 total time=  50.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.709 total time=  50.0s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.700 total time=  49.6s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.699 total time=  49.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.624 total time=   6.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.643 total time=   6.3s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.648 total time=   6.4s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.633 total time=   6.3s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.630 total time=   6.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.613 total time=   2.0s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.628 total time=   8.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.631 total time=   2.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.690 total time=  49.1s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.643 total time=   2.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.633 total time=   2.1s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.650 total time=   8.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.645 total time=   8.3s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.625 total time=   2.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.636 total time=   8.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.631 total time=   8.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.626 total time=   6.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.640 total time=   6.0s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.648 total time=   6.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.643 total time=   6.2s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.630 total time=   6.0s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.606 total time=   2.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.628 total time=   2.0s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.637 total time=   8.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.641 total time=   2.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.626 total time=   2.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.625 total time=   2.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.649 total time=   8.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.641 total time=   8.4s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.629 total time=   8.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.682 total time= 1.1min
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.622 total time=   6.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.636 total time=   6.5s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.708 total time= 1.1min
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.644 total time=   6.4s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.627 total time=   6.5s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.622 total time=   2.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.624 total time=   2.3s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.643 total time=   2.2s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=150;, score=0.629 total time=   6.8s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.626 total time=   2.3s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.624 total time=   2.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.624 total time=   8.7s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.633 total time=   8.8s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.629 total time=   8.6s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.647 total time=   8.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.628 total time=   8.8s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.700 total time= 1.1min
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.643 total time=   6.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.624 total time=   6.6s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.648 total time=   6.4s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.633 total time=   6.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.613 total time=   2.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.631 total time=   2.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.630 total time=   6.4s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.643 total time=   2.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.633 total time=   2.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.625 total time=   2.1s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.628 total time=   8.3s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.697 total time= 1.1min
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.645 total time=   8.3s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.650 total time=   8.3s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.636 total time=   8.4s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.631 total time=   8.5s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.626 total time=   6.3s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.640 total time=   6.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.648 total time=   6.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.606 total time=   2.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.630 total time=   6.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.643 total time=   6.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.628 total time=   2.0s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.641 total time=   2.0s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.626 total time=   2.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.625 total time=   2.1s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.637 total time=   8.3s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.649 total time=   8.3s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.641 total time=   8.3s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.694 total time= 1.1min
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.629 total time=   8.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.622 total time=   6.1s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.636 total time=   6.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.627 total time=   6.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.644 total time=   6.4s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.629 total time=   6.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.624 total time=   8.3s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.633 total time=   8.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.647 total time=   8.3s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.629 total time=   8.4s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.628 total time=   8.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.624 total time=  12.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.642 total time=  12.4s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.644 total time=  12.1s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.645 total time=  12.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.643 total time=  12.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.621 total time=  12.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.642 total time=  12.1s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.647 total time=  12.4s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.639 total time=  12.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.628 total time=  37.2s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.651 total time=  36.8s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.645 total time=  37.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.647 total time=  36.6s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.641 total time=  36.9s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.644 total time=  12.5s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.653 total time=  48.9s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.629 total time=  49.4s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.646 total time=  49.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.642 total time=  50.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.643 total time=  50.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.639 total time=  12.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.617 total time=  12.5s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.628 total time=  37.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.650 total time=  37.7s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.647 total time=  37.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.644 total time=  37.1s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.639 total time=  37.1s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.644 total time=  12.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.638 total time=  12.4s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.643 total time=  12.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.631 total time=  49.6s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.651 total time=  49.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.641 total time=  49.0s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.645 total time=  49.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.675 total time=   2.9s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.703 total time=   2.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.640 total time=  49.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.624 total time=  37.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.646 total time=  36.4s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.695 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.685 total time=   2.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.642 total time=  36.1s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.642 total time=  36.0s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=50;, score=0.691 total time=   2.9s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.686 total time=   8.7s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.706 total time=   8.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.714 total time=   8.4s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.701 total time=   8.5s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.639 total time=  35.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=150;, score=0.691 total time=   8.3s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.685 total time=   2.7s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.693 total time=   2.7s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.691 total time=  11.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.693 total time=   2.7s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.699 total time=   2.7s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=50;, score=0.686 total time=   2.8s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.713 total time=  11.2s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.707 total time=  11.2s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.702 total time=  11.2s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.692 total time=  11.2s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.626 total time=  47.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.646 total time=  47.4s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.686 total time=   8.4s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.709 total time=   8.5s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.706 total time=   8.6s
# [CV 1/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.669 total time=   2.9s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.640 total time=  48.0s
# [CV 2/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.691 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.713 total time=   8.8s
# [CV 5/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=150;, score=0.690 total time=   8.7s
# [CV 3/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.680 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced, rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=50;, score=0.682 total time=   2.8s
# ...
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.684 total time=  11.4s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=50;, score=0.685 total time=   3.0s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.704 total time=  11.4s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.702 total time=  11.4s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.698 total time=  11.4s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time=  11.3s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=20, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time= 1.1min
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.685 total time=   9.1s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.686 total time=   2.9s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.712 total time=   9.0s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.702 total time=   9.0s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.702 total time=   9.0s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=150;, score=0.691 total time=   8.9s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.706 total time=   2.9s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.691 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.691 total time=   3.0s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=50;, score=0.689 total time=   2.9s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.692 total time=  11.9s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.714 total time=  12.1s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.703 total time=  11.8s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.704 total time=  11.8s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.698 total time=  11.8s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.687 total time=   8.7s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.713 total time=   8.7s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.670 total time=   2.8s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.709 total time=   8.9s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.682 total time=   2.8s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.703 total time=   8.7s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=150;, score=0.694 total time=   8.9s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.690 total time=   2.9s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.679 total time=   2.7s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=50;, score=0.682 total time=   2.8s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.692 total time=  11.6s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.716 total time=  11.7s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.711 total time=  11.6s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.708 total time=  11.7s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.695 total time=  11.5s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.685 total time=   8.5s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.698 total time=   8.4s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.700 total time=   8.5s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.696 total time=   8.5s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=150;, score=0.690 total time=   8.4s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.684 total time=  11.2s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.704 total time=  11.2s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.702 total time=  11.2s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.698 total time=  11.2s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time=  11.2s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.678 total time=  16.7s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.702 total time=  16.3s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.695 total time=  16.3s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.694 total time=  16.1s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=50;, score=0.697 total time=  16.3s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.677 total time=  16.4s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.700 total time=  16.3s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.699 total time=  16.2s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.697 total time=  15.9s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.714 total time=  49.3s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.688 total time=  50.0s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.703 total time=  48.9s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.702 total time=  49.6s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=150;, score=0.699 total time=  49.8s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=50;, score=0.688 total time=  16.3s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.690 total time= 1.1min
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.713 total time= 1.1min
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.705 total time= 1.1min
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.704 total time= 1.1min
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.700 total time= 1.1min
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.667 total time=  16.6s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.699 total time=  16.4s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.684 total time=  50.0s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.712 total time=  50.5s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.701 total time=  50.7s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.711 total time=  49.5s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=150;, score=0.699 total time=  50.1s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.688 total time=  17.1s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.686 total time=  17.2s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=50;, score=0.684 total time=  17.4s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.680 total time= 1.1min
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.712 total time= 1.1min
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.705 total time= 1.2min
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.705 total time= 1.1min
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.699 total time= 1.1min
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.679 total time=  50.6s
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.709 total time=  50.5s
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.697 total time=  50.4s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.701 total time=  49.6s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=150;, score=0.693 total time=  47.2s
# [CV 1/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.677 total time= 1.0min
# [CV 2/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.710 total time= 1.0min
# [CV 3/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time=  59.4s
# [CV 4/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.698 total time=  56.5s
# [CV 5/5] END rf__class_weight=balanced_subsample, rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.694 total time=  54.9s
# Best parameters found:  {'rf__class_weight': 'balanced_subsample', 'rf__max_depth': None, 'rf__max_features': 'sqrt', 'rf__min_samples_split': 5, 'rf__n_estimators': 200}
# Best cross-validation score: 0.71
# Test set score: 0.74

# %%
# Assuming X_test and y_test are available from the function; otherwise, split your dataset similarly outside the function
y_pred = cv_params_scalar.best_estimator_.predict(X_sc)

# Compute confusion matrix
cm = confusion_matrix(y_sc, y_pred)

# Normalize the confusion matrix by row (i.e., by the number of samples in each actual class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

class_names = ['Blended', 'Denim', 'Polyester', 'Cotton', 'Wool']

# Plot normalized confusion matrix
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the figure size as necessary
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_names)

# To display percentage values in the plot, you need to enable include_values=True and adjust the formatting accordingly
disp.plot(include_values=True, cmap='viridis', ax=ax, xticks_rotation='vertical', values_format=".2%")  # values_format controls the numeric format

plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# # Test Set w/ Optimized Model Parameters

# %%
train_df = pd.read_pickle('/Users/erin/Documents/comp-viz/final-project/fabric/pkls/train_0406_scalar_non-aug.pkl')
X_train = train_df.iloc[:,2:]
y_train = train_df.iloc[:,0]

# import test set
test_df = pd.read_pickle('/Users/erin/Documents/comp-viz/final-project/fabric/pkls/test_0415.pkl')
X_test = test_df.iloc[:,2:]
y_test = test_df.iloc[:,0]

# %%
rf_model_weighted_final = RandomForestClassifier(
    n_estimators=200,             # Number of trees in the forest
    max_depth=None,               # Maximum depth of each tree
    min_samples_split=5,          # Minimum number of samples required to split an internal node
    max_features='sqrt',          # Number of features to consider when looking for the best split
    class_weight='balanced_subsample',  # Weights associated with classes based on the y values
    random_state=42               # Seed used by the random number generator for reproducibility
)

# Fit the Random Forest model
rf_model_weighted_final.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', min_samples_split=5,
#                        n_estimators=200, random_state=42)

# %%
# Predict on the test set
y_pred = rf_model_weighted_final.predict(X_test)

# Evaluate the model
print("Accuracy on Test Set: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Set: 70.46%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59      1316
#            1       0.69      0.87      0.77       519
#            2       0.76      0.63      0.69       724
#            3       0.69      0.85      0.76      1882
#            4       0.65      0.57      0.61       288
#
#     accuracy                           0.70      4729
#    macro avg       0.70      0.68      0.68      4729
# weighted avg       0.71      0.70      0.70      4729

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Normalize the confusion matrix by row (i.e., by the number of samples in each actual class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

class_names = ['Blended', 'Denim', 'Polyester', 'Cotton', 'Wool']

# Plot normalized confusion matrix
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the figure size as necessary
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_names)

# To display percentage values in the plot, you need to enable include_values=True and adjust the formatting accordingly
disp.plot(include_values=True, cmap='viridis', ax=ax, xticks_rotation='vertical', values_format=".2%")  # values_format controls the numeric format

plt.title('Normalized Confusion Matrix')
plt.show()
