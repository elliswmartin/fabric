# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
def rf_grid_search_cv(X, y, cv_folds=5):
    """
    Perform grid search cross-validation for Random Forest classifier on the given data.
    
    Parameters:
    - X: Features dataset.
    - y: Target variable dataset.
    - cv_folds: Number of folds for cross-validation.
    
    Returns:
    - grid_search: The fitted GridSearchCV object.
    """
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)
    
    # Define a pipeline with the classifier
    pipeline = Pipeline([
        ('rf', RandomForestClassifier(random_state=23))  # Random Forest classifier
    ])
    
    param_grid = {
        'rf__n_estimators': [100, 200, 300],  # Number of trees in the forest
        'rf__max_features': ['sqrt', 'log2', None],  # The number of features to consider when looking for the best split
        'rf__max_depth': [None, 10, 20, 30],  # Maximum number of levels in each decision tree
        'rf__min_samples_split': [2, 5, 10]  # Minimum number of data points placed in a node before the node is split
    }
    
    # Initialize GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid, cv=cv_folds, scoring='accuracy', verbose=3, n_jobs=-1)
    
    # Perform grid search cross-validation
    grid_search.fit(X_train, y_train)
    
    print("Best parameters found: ", grid_search.best_params_)
    print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
    
    # Optionally, evaluate on the test set
    test_score = grid_search.score(X_test, y_test)
    print("Test set score: {:.2f}".format(test_score))
    
    return grid_search

# %% [markdown]
# # Scalar Dataset - Non-Augmented

# %%
train_df_scalar = pd.read_pickle('/Users/erin/Documents/comp-viz/final-project/fabric/pkls/train_0406_scalar_non-aug.pkl')
train_df_scalar.head()
# Out:
#    label   category            0             1            2         3  \
# 0      0    Blended  3441.793288  2.028531e+07  1844.056770  0.150226
# 1      1      Denim  7211.992783  7.747671e+06  2271.840993  0.151475
# 2      2  Polyester  8856.756862  5.854463e+06  1967.259618  0.160454
# 3      0    Blended  7018.112788  7.817569e+06  1953.124972  0.152300
# 4      3     Cotton  7932.263905  6.971318e+06  2053.412469  0.157971
#
#             4         5         6         7  ...        22        23  \
# 0  346.120911  0.005210  0.000093  0.000063  ...  0.027344  0.054688
# 1  348.998260  0.004833 -0.000067  0.000038  ...  0.100000  0.048649
# 2  369.684998  0.002032 -0.000002  0.000008  ...  0.027778  0.004630
# 3  350.899200  0.004582  0.000011  0.000034  ...  0.052239  0.063433
# 4  363.965454  0.002823 -0.000003  0.000017  ...  0.030612  0.047619
#
#          24        25        26        27        28        29        30  \
# 0  0.035156  0.039062  0.031250  0.027344  0.046875  0.062500  0.050781
# 1  0.021622  0.024324  0.013514  0.021622  0.024324  0.043243  0.016216
# 2  0.004630  0.250000  0.129630  0.194444  0.018519  0.004630  0.027778
# 3  0.052239  0.007463  0.022388  0.044776  0.085821  0.074627  0.033582
# 4  0.054422  0.047619  0.051020  0.081633  0.013605  0.044218  0.047619
#
#          31
# 0  0.050781
# 1  0.070270
# 2  0.004630
# 3  0.029851
# 4  0.054422
#
# [5 rows x 34 columns]

# %%
X_sc = train_df_scalar.iloc[:,2:]
y_sc = train_df_scalar.iloc[:,0]

cv_params_scalar = rf_grid_search_cv(X_sc, y_sc)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.698 total time=   6.0s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.695 total time=   6.0s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.709 total time=   6.1s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.697 total time=   6.1s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.709 total time=   6.4s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.717 total time=  11.7s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.703 total time=  11.8s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.686 total time=   5.6s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.698 total time=  11.8s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.705 total time=  11.9s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.711 total time=  12.0s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.706 total time=   5.7s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.706 total time=   5.5s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.694 total time=   5.5s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.698 total time=   5.6s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.699 total time=  17.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.719 total time=  17.7s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time=  17.2s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.705 total time=  17.2s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.705 total time=  17.1s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.707 total time=  11.4s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.686 total time=  11.4s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.707 total time=  11.4s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.700 total time=  11.7s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.677 total time=   5.4s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.698 total time=   5.6s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.697 total time=  11.7s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.685 total time=   5.6s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.694 total time=   5.7s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.682 total time=   5.7s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  11.0s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.689 total time=  17.7s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.712 total time=  17.7s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.702 total time=  17.5s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.705 total time=  17.7s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.699 total time=  11.0s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.691 total time=  11.1s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  11.0s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.695 total time=  17.1s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.689 total time=  11.5s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.697 total time=   5.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.709 total time=   5.9s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.709 total time=   5.5s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.679 total time=  16.5s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.698 total time=   5.8s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.695 total time=   5.9s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.698 total time=  16.8s
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.690 total time=  16.3s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.693 total time=  16.8s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.698 total time=  11.6s
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.686 total time=  17.0s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.711 total time=  11.3s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.717 total time=  11.8s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.705 total time=  11.4s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.703 total time=  11.7s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.686 total time=   5.6s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.706 total time=   5.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.706 total time=   5.8s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.698 total time=   5.7s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.694 total time=   5.6s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.699 total time=  17.2s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.719 total time=  17.2s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.705 total time=  17.1s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time=  17.5s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.686 total time=  11.5s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.707 total time=  11.2s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.707 total time=  11.2s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.705 total time=  17.2s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.700 total time=  11.2s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.677 total time=   5.7s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.697 total time=  11.5s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.698 total time=   5.6s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.694 total time=   5.5s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.685 total time=   5.6s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.682 total time=   5.5s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.689 total time=  17.4s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.712 total time=  17.4s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.705 total time=  16.9s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  10.8s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.702 total time=  17.0s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.691 total time=  11.0s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.695 total time=  17.1s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.699 total time=  11.4s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.689 total time=  11.2s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  11.1s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.679 total time=  16.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.698 total time=  16.7s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.690 total time=  16.3s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.693 total time=  16.9s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.686 total time=  16.5s
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.686 total time=  32.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.708 total time=  32.4s
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.699 total time=  32.9s
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.696 total time=  32.9s
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.701 total time=  33.0s
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.683 total time=  32.8s
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.705 total time=  33.2s
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.690 total time= 1.1min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.709 total time= 1.1min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.694 total time= 1.1min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.701 total time= 1.1min
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.709 total time= 1.1min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.695 total time=  32.3s
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.687 total time=  33.0s
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.693 total time=  33.0s
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.690 total time= 1.6min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time= 1.6min
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.709 total time= 1.6min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.701 total time= 1.6min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.695 total time= 1.7min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.685 total time= 1.1min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.698 total time= 1.1min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.705 total time= 1.1min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.692 total time= 1.1min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.674 total time=  31.9s
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.703 total time= 1.1min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.697 total time=  32.1s
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.690 total time=  32.0s
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.682 total time=  31.8s
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.686 total time=  31.8s
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.708 total time= 1.6min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.687 total time= 1.7min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time= 1.1min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.695 total time= 1.6min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.694 total time= 1.6min
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.621 total time=   4.2s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.630 total time=   4.2s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.628 total time=   4.0s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.624 total time=   4.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.620 total time=   4.2s
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.700 total time= 1.1min
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.701 total time= 1.6min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.691 total time= 1.1min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.680 total time= 1.1min
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.620 total time=   8.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.631 total time=   8.5s
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time= 1.0min
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.632 total time=   8.2s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.627 total time=   8.2s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.623 total time=   8.1s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.617 total time=   4.2s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.621 total time=   4.1s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.619 total time=  12.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.628 total time=  12.4s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.629 total time=  12.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.626 total time=  12.5s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.627 total time=   4.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.618 total time=   4.1s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.624 total time=   4.1s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.623 total time=  12.3s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.621 total time=   8.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.3s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.3s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.627 total time=   8.2s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.1s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.622 total time=   4.0s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.622 total time=   4.0s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.621 total time=  12.4s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time=  12.4s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.632 total time=   4.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.622 total time=   4.0s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.626 total time=   4.0s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.629 total time=  12.2s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time=  12.5s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time=  12.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.623 total time=   8.1s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.627 total time=   8.0s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.617 total time=   8.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.702 total time= 1.6min
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.622 total time=   8.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.624 total time=   8.0s
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.680 total time= 1.6min
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.621 total time=   4.2s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.630 total time=   4.1s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.628 total time=   4.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.624 total time=   4.2s
# [CV 1/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.616 total time=  12.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.620 total time=  12.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.620 total time=   4.1s
# [CV 3/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.625 total time=  12.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.623 total time=  12.2s
# [CV 4/5] END rf__max_depth=10, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.618 total time=  12.3s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.620 total time=   8.2s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.632 total time=   8.1s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.631 total time=   8.4s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.627 total time=   8.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.623 total time=   8.2s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.621 total time=   4.0s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.617 total time=   4.1s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.627 total time=   4.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.618 total time=   4.2s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.619 total time=  12.4s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.624 total time=   4.1s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.628 total time=  12.3s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.629 total time=  12.4s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.626 total time=  12.4s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.623 total time=  12.7s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.621 total time=   8.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.3s
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.692 total time= 1.6min
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.2s
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.681 total time= 1.6min
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.627 total time=   8.1s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.626 total time=   8.1s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.622 total time=   4.2s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.622 total time=   4.1s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.632 total time=   4.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.622 total time=   4.0s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.626 total time=   4.1s
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.697 total time= 1.6min
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.621 total time=  12.3s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.629 total time=  12.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time=  12.5s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time=  12.3s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.617 total time=   8.2s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time=  12.4s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.623 total time=   8.3s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.622 total time=   8.2s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.627 total time=   8.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.624 total time=   8.2s
# [CV 1/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.616 total time=  12.5s
# [CV 2/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.620 total time=  12.2s
# [CV 3/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.625 total time=  12.3s
# [CV 4/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.618 total time=  12.2s
# [CV 5/5] END rf__max_depth=10, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.623 total time=  12.1s
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.624 total time=  23.4s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.648 total time=  23.7s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.644 total time=  23.7s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.636 total time=  23.7s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.641 total time=  23.8s
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.626 total time=  23.8s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.646 total time=  23.9s
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.630 total time=  48.6s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.653 total time=  48.4s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.646 total time=  48.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.632 total time=  48.3s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.643 total time=  48.0s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.642 total time=  25.0s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.635 total time=  24.6s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.639 total time=  25.0s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.653 total time= 1.2min
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.631 total time= 1.2min
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.644 total time= 1.2min
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.633 total time= 1.2min
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.642 total time= 1.2min
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.628 total time=  49.8s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.650 total time=  48.7s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.643 total time=  47.9s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.633 total time=  48.1s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.643 total time=  23.6s
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.620 total time=  23.8s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.643 total time=  47.5s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.640 total time=  24.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.632 total time=  23.4s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.637 total time=  23.6s
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.627 total time= 1.2min
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.650 total time= 1.2min
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.627 total time=  47.6s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.633 total time= 1.2min
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.644 total time= 1.2min
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.692 total time=   5.6s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.702 total time=   5.6s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.641 total time= 1.2min
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.703 total time=   5.6s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.704 total time=   5.7s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.643 total time=  47.3s
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.648 total time=  47.3s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.630 total time=  47.4s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.695 total time=   5.6s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.640 total time=  48.3s
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.696 total time=  11.4s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.714 total time=  11.4s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.708 total time=  11.3s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.702 total time=  11.7s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.701 total time=  11.1s
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.685 total time=   5.6s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.707 total time=   5.6s
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.694 total time=  16.8s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.700 total time=   5.6s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time=  17.1s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.705 total time=   5.5s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.692 total time=   5.7s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.697 total time=  17.1s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.708 total time=  17.3s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.706 total time=  17.7s
# [CV 1/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.625 total time= 1.2min
# [CV 2/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.648 total time= 1.2min
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.688 total time=  11.2s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.704 total time=  11.3s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.711 total time=  11.2s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.701 total time=  11.1s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.690 total time=  11.4s
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.671 total time=   5.4s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.693 total time=   5.5s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.688 total time=   5.5s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.683 total time=   5.5s
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.688 total time=  16.8s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.679 total time=   5.5s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.706 total time=  17.0s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.705 total time=  16.8s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.703 total time=  17.0s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.693 total time=  16.7s
# [CV 3/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.642 total time= 1.2min
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.680 total time=  11.1s
# [CV 4/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.631 total time= 1.2min
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.692 total time=  11.3s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.691 total time=  11.2s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.690 total time=  11.3s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  11.2s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.692 total time=   5.8s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.702 total time=   5.8s
# [CV 5/5] END rf__max_depth=10, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.639 total time= 1.2min
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.703 total time=   5.5s
# [CV 1/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.679 total time=  16.4s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.704 total time=   5.6s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.695 total time=   5.7s
# [CV 2/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.693 total time=  16.5s
# [CV 5/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.684 total time=  16.1s
# [CV 3/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.692 total time=  16.6s
# [CV 4/5] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.692 total time=  16.6s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.696 total time=  11.5s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.714 total time=  11.4s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.708 total time=  11.9s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.702 total time=  11.2s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.701 total time=  11.6s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.685 total time=   5.6s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.707 total time=   5.8s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.700 total time=   5.9s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.705 total time=   5.7s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.692 total time=   5.9s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.694 total time=  17.2s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time=  17.4s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.706 total time=  17.6s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.688 total time=  11.2s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.708 total time=  17.4s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.704 total time=  11.4s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.697 total time=  17.3s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.711 total time=  11.8s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.701 total time=  11.5s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.690 total time=  11.7s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.671 total time=   5.5s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.693 total time=   5.7s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.688 total time=   5.4s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.679 total time=   5.3s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.683 total time=   5.7s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.688 total time=  17.0s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.706 total time=  17.2s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.680 total time=  11.1s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.703 total time=  17.0s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.705 total time=  17.5s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.693 total time=  17.0s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.692 total time=  11.1s
# [CV 3/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.691 total time=  10.9s
# [CV 4/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.690 total time=  11.1s
# [CV 5/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  10.8s
# [CV 2/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.693 total time=  16.2s
# [CV 1/5] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.679 total time=  16.7s
# ...
# [CV 2/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.709 total time=  11.4s
# [CV 4/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.701 total time=  11.1s
# [CV 5/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.697 total time=  11.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.679 total time=   5.6s
# [CV 1/5] END rf__max_depth=20, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.678 total time= 1.6min
# [CV 2/5] END rf__max_depth=20, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.702 total time= 1.6min
# [CV 2/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.697 total time=   5.6s
# [CV 1/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.688 total time=  17.2s
# [CV 2/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.714 total time=  17.3s
# [CV 3/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.694 total time=   5.5s
# [CV 4/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.687 total time=   5.5s
# [CV 5/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.682 total time=   5.5s
# [CV 3/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.705 total time=  16.8s
# [CV 4/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.703 total time=  16.9s
# [CV 5/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.696 total time=  16.9s
# [CV 1/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  11.0s
# [CV 2/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.700 total time=  11.1s
# [CV 4/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.690 total time=  11.0s
# [CV 3/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.690 total time=  11.3s
# [CV 5/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.684 total time=  11.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.693 total time=   5.9s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.708 total time=   5.7s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.711 total time=   5.8s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.699 total time=   5.7s
# [CV 1/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.681 total time=  16.9s
# [CV 2/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.698 total time=  16.3s
# [CV 3/5] END rf__max_depth=20, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.690 total time= 1.6min
# [CV 3/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.692 total time=  16.9s
# [CV 4/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.689 total time=  16.9s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.700 total time=   6.0s
# [CV 4/5] END rf__max_depth=20, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.682 total time= 1.6min
# [CV 5/5] END rf__max_depth=30, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.687 total time=  16.5s
# [CV 5/5] END rf__max_depth=20, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.700 total time= 1.6min
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.699 total time=  11.4s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.715 total time=  11.3s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.709 total time=  11.5s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.707 total time=  11.7s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.687 total time=   5.7s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.705 total time=  11.7s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.705 total time=   5.5s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.698 total time=   5.6s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.702 total time=   5.8s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.694 total time=   5.6s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.699 total time=  17.3s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time=  17.1s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.718 total time=  17.3s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.708 total time=  17.4s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.707 total time=  17.5s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.705 total time=  11.2s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.709 total time=  11.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.688 total time=  11.5s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.701 total time=  11.7s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.697 total time=  11.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.679 total time=   5.6s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.697 total time=   5.6s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.687 total time=   5.3s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.694 total time=   5.4s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.682 total time=   5.6s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.688 total time=  16.9s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.714 total time=  17.2s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.705 total time=  17.1s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time=  11.1s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.703 total time=  16.8s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.700 total time=  11.4s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.696 total time=  16.9s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.690 total time=  11.1s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.684 total time=  10.8s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.690 total time=  11.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.681 total time=  16.5s
# [CV 2/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.698 total time=  16.4s
# [CV 3/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.692 total time=  16.9s
# [CV 4/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.689 total time=  16.3s
# [CV 5/5] END rf__max_depth=30, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.687 total time=  16.6s
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.711 total time=  32.1s
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.687 total time=  33.0s
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.702 total time=  32.4s
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.696 total time=  33.0s
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.701 total time=  33.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.681 total time=  32.7s
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.706 total time=  33.4s
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.690 total time= 1.1min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.710 total time= 1.1min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.702 total time= 1.1min
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.692 total time= 1.1min
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.708 total time= 1.1min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.695 total time=  32.4s
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.695 total time=  32.0s
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.690 total time=  32.7s
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.691 total time= 1.6min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.711 total time= 1.6min
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.706 total time= 1.6min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.700 total time= 1.6min
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=300;, score=0.697 total time= 1.6min
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.686 total time= 1.1min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.705 total time= 1.1min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.698 total time= 1.1min
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.692 total time= 1.1min
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=200;, score=0.702 total time= 1.1min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.697 total time=  31.9s
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.673 total time=  32.1s
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.690 total time=  32.7s
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.682 total time=  31.6s
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=100;, score=0.688 total time=  31.3s
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.687 total time= 1.6min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.707 total time= 1.6min
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.683 total time= 1.1min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.696 total time= 1.6min
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.694 total time= 1.6min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.699 total time= 1.0min
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=300;, score=0.701 total time= 1.6min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.691 total time= 1.0min
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.680 total time= 1.0min
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=200;, score=0.695 total time= 1.0min
# [CV 1/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.680 total time= 1.5min
# [CV 2/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.701 total time= 1.4min
# [CV 3/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.692 total time= 1.4min
# [CV 4/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.682 total time= 1.4min
# [CV 5/5] END rf__max_depth=30, rf__max_features=None, rf__min_samples_split=10, rf__n_estimators=300;, score=0.697 total time= 1.3min
# Best parameters found:  {'rf__max_depth': 30, 'rf__max_features': 'sqrt', 'rf__min_samples_split': 2, 'rf__n_estimators': 300}
# Best cross-validation score: 0.71
# Test set score: 0.75

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Assuming X_test and y_test are available from the function; otherwise, split your dataset similarly outside the function
y_pred = cv_params_scalar.best_estimator_.predict(X_sc)

# Compute confusion matrix
cm = confusion_matrix(y_sc, y_pred)

# Normalize the confusion matrix by row (i.e., by the number of samples in each actual class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

class_names = ['Blended', 'Denim', 'Polyester', 'Cotton', 'Wool']

# Plot normalized confusion matrix
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the figure size as necessary
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_names)

# To display percentage values in the plot, you need to enable include_values=True and adjust the formatting accordingly
disp.plot(include_values=True, cmap='viridis', ax=ax, xticks_rotation='vertical', values_format=".2%")  # values_format controls the numeric format

plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# # Test Set w/ Optimized Model Parameters

# %% [markdown]
# # Vectorized Feature Dataset - Non-Augmented

# %%
train_df_vectorized = pd.read_pickle('/Users/erin/Documents/comp-viz/final-project/fabric/pkls/train_0410_vectorized_non-aug.pkl')
train_df_vectorized.head()
# Out:
#    label   category           0          1          2           3          4  \
# 0      0    Blended  216.875773 -21.220328  31.355705  113.803698  67.469517
# 1      1      Denim   -6.478218 -44.845392   9.334029    0.559372  -5.535237
# 2      2  Polyester  -21.765612  15.511845   0.440996    7.523796 -23.242091
# 3      0    Blended    1.031767 -13.747633 -35.657890   10.977205   4.696071
# 4      3     Cotton   -9.987670 -17.112746 -15.962529  -15.739822  -1.963229
#
#            5          6          7  ...      6822      6823      6824  \
# 0  51.739112  32.134906 -34.037195  ... -0.664340 -1.337023 -0.017352
# 1   2.069803   1.668050  -2.671548  ...  0.196028  0.417297 -0.643817
# 2  -0.555019  -0.387093   2.955491  ...  0.123217  0.683356  0.218428
# 3   1.991713   0.734960   4.531688  ... -0.123557 -0.207327 -0.153230
# 4  -4.441544   0.110439  -1.643463  ...  0.713136  0.477264 -0.658661
#
#        6825      6826      6827      6828      6829      6830      6831
# 0 -0.616874 -0.858821 -0.282316  1.121574  0.521872  0.946164 -0.098814
# 1  1.078271  0.301808 -1.118499 -0.406229  0.275195 -0.698774  0.043567
# 2  0.273425 -0.274362  0.532576  0.547632 -0.846333  0.320085 -1.747008
# 3  1.045500  0.740585 -0.987832 -1.463705  1.176062  0.128055  0.676635
# 4 -0.692280 -0.230699  1.451385 -1.054964 -0.210731 -0.705949 -0.167371
#
# [5 rows x 6834 columns]

# %%
X_vec = train_df_vectorized.iloc[:,2:]
y_vec = train_df_vectorized.iloc[:,0]

cv_params_vector = rf_grid_search_cv(X_vec, y_vec)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.380 total time= 2.5min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.384 total time= 2.6min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.387 total time= 2.6min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.386 total time= 2.6min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=100;, score=0.379 total time= 2.6min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.385 total time= 2.4min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.384 total time= 2.4min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.378 total time= 5.0min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.383 total time= 5.1min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.376 total time= 5.1min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.379 total time= 5.1min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=200;, score=0.378 total time= 5.1min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.379 total time= 2.4min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.382 total time= 2.5min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.381 total time= 7.5min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.377 total time= 7.5min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=100;, score=0.383 total time= 2.5min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.387 total time= 4.8min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.386 total time= 4.9min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.377 total time= 7.4min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.378 total time= 4.9min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.384 total time= 4.9min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.375 total time= 7.5min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=2, rf__n_estimators=300;, score=0.384 total time= 7.6min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.388 total time=17.6min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.378 total time=17.6min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=200;, score=0.381 total time=20.1min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.384 total time=17.6min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.391 total time=17.6min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=100;, score=0.386 total time=17.6min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.380 total time=38.7min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.384 total time=38.7min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.381 total time=38.8min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.379 total time=38.9min
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.383 total time=36.3min
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.357 total time=  24.2s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.349 total time=  24.2s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.347 total time=  24.4s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.355 total time=  24.2s
# /Users/erin/anaconda3/envs/tanlp/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=100;, score=0.358 total time=  25.7s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.352 total time=  52.9s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.357 total time=  53.0s
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.376 total time=21.1min
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.381 total time=21.1min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.384 total time=21.2min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=200;, score=0.384 total time=21.1min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=5, rf__n_estimators=300;, score=0.378 total time=38.8min
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.356 total time=  56.3s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.357 total time=  56.2s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=200;, score=0.353 total time=  57.8s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.353 total time=  32.6s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.359 total time=18.4min
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.353 total time=17.5min
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.356 total time=18.4min
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.353 total time=18.4min
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.353 total time=18.4min
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.357 total time=17.4min
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.351 total time=  25.4s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=100;, score=0.357 total time=  26.5s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=2, rf__n_estimators=300;, score=0.351 total time=18.4min
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.355 total time=  48.1s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.353 total time=  47.7s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.358 total time=  48.4s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.355 total time=  48.4s
# [CV 1/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.383 total time=40.7min
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=200;, score=0.357 total time=  48.3s
# [CV 2/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.383 total time=40.7min
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.351 total time=  24.6s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.352 total time=  25.0s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.348 total time=  25.1s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.355 total time= 1.2min
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.349 total time=  25.0s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.349 total time= 1.2min
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=100;, score=0.359 total time=  25.8s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.352 total time= 1.3min
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.353 total time= 1.3min
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=5, rf__n_estimators=300;, score=0.349 total time= 1.3min
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.354 total time=  51.5s
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.354 total time=  51.8s
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.354 total time=  52.1s
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.351 total time=  51.9s
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=200;, score=0.355 total time=  53.2s
# [CV 1/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.358 total time= 1.3min
# [CV 2/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.356 total time= 1.4min
# [CV 3/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.352 total time= 1.3min
# [CV 4/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.349 total time= 1.3min
# [CV 3/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.375 total time=24.6min
# [CV 5/5] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_split=10, rf__n_estimators=300;, score=0.355 total time= 1.4min
# [CV 4/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.376 total time=24.7min
# [CV 5/5] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_split=10, rf__n_estimators=300;, score=0.379 total time=24.7min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.457 total time=419.1min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.460 total time=421.9min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.445 total time=423.0min
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.456 total time=441.7min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=100;, score=0.447 total time=443.4min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.464 total time=771.8min
# [CV 3/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.455 total time=778.8min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.457 total time=784.7min
# [CV 2/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.464 total time=344.6min
# [CV 1/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=5, rf__n_estimators=100;, score=0.451 total time=346.7min
# [CV 4/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.454 total time=788.3min
# [CV 5/5] END rf__max_depth=None, rf__max_features=None, rf__min_samples_split=2, rf__n_estimators=200;, score=0.465 total time=800.3min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 X_vec = train_df_vectorized.iloc[:,2:]
#       2 y_vec = train_df_vectorized.iloc[:,0]
# ----> 4 cv_params_vector = rf_grid_search_cv(X_vec, y_vec)
#
# Cell In[7], line 33, in rf_grid_search_cv(X, y, cv_folds)
#      30 grid_search = GridSearchCV(pipeline, param_grid, cv=cv_folds, scoring='accuracy', verbose=3, n_jobs=-1)
#      32 # Perform grid search cross-validation
# ---> 33 grid_search.fit(X_train, y_train)
#      35 print("Best parameters found: ", grid_search.best_params_)
#      36 print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/anaconda3/envs/tanlp/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %% [markdown]
# This would truly need to be run in a parallelized fashion, breaking the grid up into multiple kernels and likely done on the cloud paying for memory. Beyond that, the scores were not promising *at all* -- I think to make vectorized features worth it in this case, we may need to add more features and computational power.
