# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %% [markdown]
# ### SVM - Multi-Class Classifier
#
#
# The function below takes in a test DF, features (which we can modified in the event we have thousands of columns and they are named numerically -- in this case we just need to drop the target variable to define X). It runs cross validation to determine the best hyperparameters to be used for the support vector machine model, returning a grid search object with the following attributes (per ChatGPT):
#
# <b>Attributes</b>
# * best_estimator_: The estimator that was chosen by the search, i.e., the estimator which gave highest score (or smallest loss if specified) on the left out data. Not available if refit=False.
# * best_score_: The score of the best_estimator on the left out data.
# * best_params_: The parameter setting that gave the best results on the hold out data.
# * best_index_: The index (of the cv_results_ arrays) which corresponds to the best candidate parameter setting.
# * cv_results_: A dictionary with keys as column headers and values as columns, that can be imported into a pandas DataFrame. This attribute provides scores, fit times, score times, and parameters for all the candidate models. It contains a lot of detailed information for each parameter combination that was evaluated.
# * scorer_: The function or a dictionary of functions that scores the predictions on the test set.
# * n_splits_: The number of cross-validation splits (folds/iterations).
# * refit_time_: Time for refitting the best estimator on the whole dataset (available only if refit is set to True).
#
# <b>Methods</b>
# * fit(X, y=None, groups=None): Run fit with all sets of parameters.
# * predict(X): Call predict on the estimator with the best found parameters.
# * score(X, y=None): Returns the score on the given data, if the estimator has been refit.
# * predict_proba(X): Call predict_proba on the estimator with the best found parameters, if available.
# * decision_function(X): Call decision_function on the estimator with the best found parameters, if available.
# * transform(X): Call transform on the estimator with the best found parameters, if available.
# * inverse_transform(X): Call inverse_transform on the estimator with the best found parameters, if available.

# %%
train_df = pd.read_pickle('pkls/train_0413_vectorized_down.pkl')
train_df.head(20)
# Out:
#     label   category          0          1          2         3          4  \
# 0       0  Polyester -22.551701   6.640250 -20.073006 -0.185993   8.064456
# 1       1    Blended   2.222189  12.023860   5.728983 -0.401612  -3.781469
# 2       2     Cotton  -8.782349 -10.419778  -3.230320 -3.560026 -12.025969
# 3       2     Cotton -20.276441   8.068111  -2.238266  0.931149   1.719901
# 4       1    Blended  -2.843181  12.285835  -0.216659  1.353190 -20.352959
# 5       3      Denim   8.421888   6.034292  -8.507028  1.936601   2.704873
# 6       1    Blended  82.946419 -33.574327 -16.782731 -9.845254  -4.025645
# 7       0  Polyester -18.539184 -12.510181  -2.825878 -2.708091   7.373353
# 8       3      Denim  -4.812139  -2.610106  -4.532656 -2.981704 -11.382960
# 9       4       Wool  -7.355473   6.923264   1.495470  3.413331  10.099049
# 10      3      Denim   4.675559  -2.855380   5.393104 -4.647989 -11.423359
# 11      4       Wool  -7.364067  -8.197363   2.175002 -2.359397   5.200387
# 12      1    Blended -30.031519  -5.629759   4.843019  0.507371   3.043272
# 13      4       Wool  -3.578443   3.630327   3.205417 -5.679341  -4.238228
# 14      3      Denim  -1.899581   2.176205   6.655573  8.440256   6.331668
# 15      1    Blended -17.929229   5.504559   0.386755  1.294020   9.176122
# 16      1    Blended  -5.294696   7.456639  13.418994  3.352028   3.319563
# 17      2     Cotton  17.084308   4.598734  -7.876900 -2.057124  -0.350089
# 18      0  Polyester -31.939895   1.419995   1.212746 -0.133383  -0.240558
# 19      3      Denim -10.733166  -3.371619   6.876746 -0.721907 -16.100433
#
#             5         6         7  ...      5648      5649      5650  \
# 0    3.086276  0.405081 -0.250178  ... -0.855946 -0.161253  0.279503
# 1  -17.061027 -1.394012  0.867621  ...  0.248079  1.212758  0.802891
# 2   -7.576741  0.866104 -2.751589  ... -1.084096 -0.701471  0.517012
# 3   16.556287 -2.032563  0.143973  ... -1.425926 -1.101695 -2.290515
# 4   -0.615363  2.141893  2.760234  ... -0.382633 -1.855078  0.859940
# 5   17.343551 -1.911905  2.050036  ...  1.006669  0.140831  0.621697
# 6    1.208493  6.565539  5.914786  ... -0.170071  0.447938  0.035537
# 7   -0.706569  0.308168 -1.940498  ...  0.508448 -0.917669 -0.456928
# 8   -9.848374  4.081369 -2.726554  ... -0.113101  0.219479 -1.261016
# 9    3.907318  2.289290  0.319297  ... -0.079263  0.323361  1.317793
# 10  10.459755 -0.177418  5.046075  ...  0.362495  0.430415 -1.282750
# 11  10.022689  3.269777  4.239217  ...  0.889805  0.224188 -1.070090
# 12  11.796192 -0.418733  1.508862  ... -0.466631 -0.371187  0.975668
# 13   0.454253 -1.468520 -3.510360  ...  0.197255  0.053795  0.032887
# 14 -19.853824 -2.023300  0.888941  ... -0.378682  0.114102 -1.761149
# 15   6.358386  1.264200 -0.651912  ...  0.298760 -0.439997 -1.643820
# 16  15.533160  0.856378  4.128395  ...  0.351088 -0.188592  1.442062
# 17   6.429081 -2.688733 -4.009814  ... -0.159603 -0.443273 -0.682149
# 18   8.804493 -2.970506  1.917328  ...  2.092893  0.468592  0.209877
# 19   2.463859  5.459014 -1.958263  ... -0.234286 -0.503785 -0.341920
#
#         5651      5652      5653      5654      5655      5656      5657
# 0   1.123687 -0.747291 -1.427637 -0.864267 -1.627084  0.840153  0.984637
# 1   0.857112 -0.487407  0.205473 -0.093273 -0.434769 -0.839447  1.246764
# 2   1.133394  0.053130  0.238023  0.267592  1.202482 -1.339125 -0.218224
# 3  -0.060351  1.230575 -0.822555  0.334763  0.058376  0.326840  1.382755
# 4   0.354477 -0.032276  0.082259  1.169042 -0.800400  0.412196  0.017733
# 5   0.137481 -1.013575  0.144374 -0.618356 -0.476146  1.025937 -0.103931
# 6   0.495224  0.579586  0.323927 -0.285633  0.651825 -1.057709 -0.527152
# 7  -0.411915 -1.387184  1.077967 -1.722401 -1.115223  0.819296  1.188422
# 8  -0.547008  0.080604 -0.012537 -0.569565  0.102632 -0.237847 -1.462368
# 9  -0.699424  1.757832  1.664485 -0.758179 -0.260213 -0.513439 -2.191245
# 10  0.038492 -0.480388  0.247926 -1.029606 -0.312731 -0.415038 -0.195479
# 11 -0.470597  2.140667 -0.276213  0.523749  1.031038  0.581629 -0.981279
# 12 -0.027264 -1.216217  0.288106  1.295394 -0.024929  1.202198  0.499600
# 13  0.210893 -0.510378 -0.174945  1.336259 -0.296833 -0.280084  0.048468
# 14  0.672207 -0.103056  0.098376  0.958704  0.831581  1.102222  0.682956
# 15 -0.041007 -1.411267 -0.237629 -0.652257 -1.083555  0.210815 -0.180800
# 16  1.527279  0.812360  1.213741 -0.125395 -1.008110  0.578223  0.153493
# 17 -1.199111  0.328787 -2.228546 -0.821020 -0.049199 -1.011468  0.741260
# 18  0.340172 -0.594675 -0.196650  0.037156  0.452067  0.583358 -0.884341
# 19  0.992548 -0.716088 -1.414565 -0.063004  1.207043 -1.430568 -0.880907
#
# [20 rows x 5660 columns]

# %%
def svm_grid_search_cv(X, y, cv_folds=5):
    """
    Perform grid search cross-validation for SVM classifier on the given dataframe.
    
    Parameters:
    # - dataframe: The pandas DataFrame containing the dataset.
    # - features: List of column names to be used as features.
    - target: The name of the column to be used as the target variable.
    - cv_folds: Number of folds for cross-validation.
    
    Returns:
    - grid_search: The fitted GridSearchCV object.
    """
    
    # # Separate the features and the target variable
    # X = dataframe[features]
    # y = dataframe[target]
    
    # Split the data into training and testing sets (optional, could also perform CV on the entire dataset)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)
    
    # Define a pipeline that includes scaling and the classifier
    pipeline = Pipeline([
        ('scaler', StandardScaler()),  # Feature scaling is important for SVM
        ('svm', SVC(probability=True))  # SVM classifier
    ])
    
    # Parameter grid for GridSearchCV
    param_grid = {
        'svm__C': [0.1, 1, 10],  # SVM regularization parameter
        'svm__kernel': ['linear', 'rbf'],  # Kernel type to be used in the algorithm
        'svm__gamma': ['scale', 'auto']  # Kernel coefficient for 'rbf', 'poly' and 'sigmoid'
    }
    
    # Initialize GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid, cv=cv_folds, scoring='accuracy', verbose=3, n_jobs=-1)
    
    # Perform grid search cross-validation
    grid_search.fit(X_train, y_train)
    
    print("Best parameters found: ", grid_search.best_params_)
    print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
    
    # Optionally, evaluate on the test set
    test_score = grid_search.score(X_test, y_test)
    print("Test set score: {:.2f}".format(test_score))
    
    return grid_search

# %%
X = train_df.iloc[:,2:] #best features according to PCA 
y = train_df.iloc[:,0] #numerical labels

cv_params = svm_grid_search_cv(X, y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 4/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.354 total time=58.0min
# [CV 5/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.372 total time=58.5min
# [CV 2/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.352 total time=58.7min
# [CV 1/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.354 total time=59.2min
# [CV 3/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.364 total time=59.3min
# [CV 2/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.217 total time=67.0min
# [CV 1/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.222 total time=67.1min
# [CV 4/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.214 total time=67.1min
# [CV 5/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.216 total time=67.1min
# [CV 3/5] END svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.211 total time=67.3min
# [CV 2/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.352 total time=54.1min
# [CV 1/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.354 total time=54.6min
# [CV 4/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.354 total time=54.2min
# [CV 3/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.364 total time=54.9min
# [CV 5/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.372 total time=54.8min
# [CV 1/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.222 total time=63.5min
# [CV 3/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.211 total time=63.5min
# [CV 2/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.217 total time=63.6min
# [CV 4/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.214 total time=63.5min
# [CV 5/5] END svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.216 total time=63.8min
# [CV 2/5] END svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.352 total time=55.1min
# [CV 1/5] END svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.354 total time=55.7min
# [CV 4/5] END svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.354 total time=55.5min
# [CV 3/5] END svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.364 total time=56.4min
# [CV 5/5] END svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.372 total time=55.7min
# [CV 1/5] END svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.401 total time=64.1min
# [CV 2/5] END svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.394 total time=64.1min
# [CV 4/5] END svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.411 total time=64.1min
# [CV 3/5] END svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.402 total time=64.1min
# [CV 5/5] END svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.399 total time=64.3min
# [CV 1/5] END svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.354 total time=55.0min
# [CV 2/5] END svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.352 total time=55.3min
# [CV 4/5] END svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.354 total time=54.7min
# [CV 3/5] END svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.364 total time=55.5min
# [CV 5/5] END svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.372 total time=55.2min
# [CV 1/5] END svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.401 total time=64.7min
# [CV 2/5] END svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.394 total time=64.7min
# [CV 3/5] END svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.402 total time=64.8min
# [CV 4/5] END svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.411 total time=64.8min
# [CV 5/5] END svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.399 total time=64.9min
# [CV 1/5] END svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.354 total time=56.5min
# [CV 2/5] END svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.352 total time=55.8min
# [CV 4/5] END svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.354 total time=56.0min
# [CV 3/5] END svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.364 total time=56.7min
# [CV 5/5] END svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.372 total time=56.8min
# [CV 1/5] END svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.412 total time=64.8min
# [CV 2/5] END svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.419 total time=64.8min
# [CV 4/5] END svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.433 total time=64.8min
# [CV 3/5] END svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.418 total time=64.9min
# [CV 5/5] END svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.417 total time=65.0min
# [CV 1/5] END svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.354 total time=55.3min
# [CV 2/5] END svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.352 total time=55.4min
# [CV 4/5] END svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.354 total time=54.6min
# [CV 3/5] END svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.364 total time=55.6min
# [CV 5/5] END svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.372 total time=54.8min
# [CV 1/5] END svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.412 total time=48.8min
# [CV 2/5] END svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.419 total time=48.8min
# [CV 3/5] END svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.418 total time=48.8min
# [CV 4/5] END svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.433 total time=48.7min
# [CV 5/5] END svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.417 total time=48.6min
# Best parameters found:  {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.42
# Test set score: 0.47

# %%
# Assuming X_test and y_test are available from the function; otherwise, split your dataset similarly outside the function
y_pred = cv_params.best_estimator_.predict(X)

# Compute confusion matrix
cm = confusion_matrix(y, y_pred)

class_names = ['Blended', 'Denim', 'Polyester', 'Cotton', 'Wool']

# Plot confusion matrix
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the figure size as necessary
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

# To improve readability, you might not want to display labels for all classes if there are many of them
disp.plot(include_values=False, cmap='viridis', ax=ax, xticks_rotation='vertical')
# disp.plot(cmap='viridis', ax=ax, xticks_rotation='vertical')

plt.show()

# %% [markdown]
# # Apply trained model to test set

# %%
#We need the test file to have the same features (columns) as the train set
test_df = pd.read_pickle('pkls/test_0414_vectorized_down_PCA.pkl')
test_df.head(20)
# Out:
#     label   category          0          1          2          3          4  \
# 0       0  Polyester  15.328683  17.616656  10.707067   5.559285  -6.604408
# 1       2     Cotton -36.651415  -2.642936   2.448792  -1.856710   6.835747
# 2       1    Blended  74.728364  25.701788  25.922483  13.286841  -2.204635
# 3       2     Cotton  31.698155   4.875697  -7.221352   0.235734  -8.859742
# 4       2     Cotton  -6.533931 -10.000209 -11.311474  -8.388511  -4.207723
# 5       1    Blended -29.367358 -12.046716   1.174766  -3.775542   3.103036
# 6       1    Blended -13.062167   2.986538  -4.604290   3.764723   4.396177
# 7       1    Blended  -9.307239   5.899271  -1.861625   1.201135   2.273920
# 8       0  Polyester -31.335096   0.568916  -0.647773   4.037464  18.303421
# 9       2     Cotton -14.174407  13.591362   8.597431   3.239881  -6.804803
# 10      1    Blended  -8.654855 -11.115407  -0.443384  -3.647548  -0.524756
# 11      2     Cotton   0.486203   3.486330 -14.509008  -0.058601  -6.690468
# 12      2     Cotton -28.210519   8.928002   5.211184   0.387856  -7.805988
# 13      3      Denim  -3.010262  15.947998 -11.056601  -0.874646 -13.893166
# 14      3      Denim  63.220827 -23.902704  -4.373408  69.248501 -19.752729
# 15      2     Cotton  67.985928   3.288363  12.758948  -1.713892  -3.148424
# 16      2     Cotton -30.096107   2.437837   7.648524   2.814185  -3.525348
# 17      0  Polyester -38.489411   7.197308   0.418366   2.025208  17.412223
# 18      2     Cotton -23.495150   4.220343   6.479254   1.272009  -8.480389
# 19      0  Polyester -16.493365   0.748068   3.696562  -2.765433  -6.330117
#
#             5          6          7  ...      5648      5649      5650  \
# 0   -3.477950   1.186056  -3.803337  ...  0.718617  1.355302  1.164032
# 1   -3.228036  -0.182077  -1.554097  ...  0.648908 -0.768114 -0.423001
# 2   -2.134058   9.618914  17.946711  ... -0.851140  0.662784  2.128726
# 3    8.613435   3.787533  -3.674418  ...  0.757492 -0.102012 -0.966182
# 4   -7.127563  -0.671725  -2.073065  ... -0.094105 -0.450736  1.454135
# 5   -2.481101   1.666719   1.810950  ...  1.002351  0.002627  0.118653
# 6  -19.881709   0.076074  -2.490287  ... -0.232039 -0.827782 -0.512008
# 7    1.398642  -1.704763   2.645909  ...  0.368809 -0.065881  1.674878
# 8   -1.583281  -0.349976   0.248269  ...  0.697748  0.652399 -0.728419
# 9   20.071957  -2.763637   4.620302  ... -1.083591 -0.080313  0.017933
# 10 -20.755743  -0.394125  -1.515297  ... -0.572455  1.118363  1.175671
# 11 -10.037768  -0.064904   6.513335  ...  0.887521  0.806850  0.489958
# 12  -2.029954   0.346033   2.960391  ...  0.281143 -0.633446 -0.192924
# 13  -3.143651  -0.872706   0.302135  ... -1.259568 -1.848707  1.193468
# 14   2.809024  82.050698  -9.439986  ...  0.451265  0.839693  0.677438
# 15   7.687611  -3.552332   1.759607  ...  0.809874  0.167784 -1.070749
# 16 -12.120933  -0.108307  -1.683963  ...  0.639133 -1.644753 -0.706624
# 17   1.795045  -0.537996  -0.638874  ... -0.277003  0.730683  1.106323
# 18 -10.978981   1.360529  -1.984847  ... -0.428145 -0.770900  1.329991
# 19  -6.334629   0.223262  -1.687355  ...  0.066182 -0.297268  0.297188
#
#         5651      5652      5653      5654      5655      5656      5657
# 0   0.425006 -1.116067  0.426226 -0.701364  1.888854  0.294269  1.369952
# 1  -0.131465 -1.210073 -1.270067 -0.197960 -0.248717  0.081885  1.166406
# 2   0.162963 -0.356982  1.194788  0.396272  1.361204  1.774866 -1.400055
# 3   0.179029 -1.434259 -0.586591  2.739673  0.416369 -1.267883  2.263752
# 4  -0.297901  0.377320  2.169895  1.399824  0.385715 -0.911349 -0.353056
# 5   0.626634  0.482887 -0.279757 -0.695340  0.475808 -0.077755 -1.354286
# 6  -0.174994  0.569997  0.681669 -0.795263 -0.210152  0.674840 -0.379702
# 7   1.563705 -0.688745  0.214543 -0.488534  0.631342  0.651113 -0.888893
# 8  -0.551822 -0.201835  0.042023 -0.814296 -0.422660 -0.102764 -0.168838
# 9   0.915318  0.555851  0.014012  0.420064 -0.212148 -0.949745 -0.547129
# 10  0.162023  0.316681 -0.531326  0.712372  0.197866 -0.716851 -0.277941
# 11 -0.491915  0.159103 -0.029608 -1.089089  0.325891 -0.557832 -0.257801
# 12  0.178222  0.806984  0.103700  0.080257 -0.208390  1.153791 -0.797552
# 13 -0.443480  1.099693  1.376445 -0.122906  0.177580 -1.141799 -1.440988
# 14  0.198959 -1.266593 -0.056143  1.269809  0.272981 -0.650710  0.234015
# 15 -0.413645  0.052587  0.740866  0.551093 -0.330062  1.055830  0.753416
# 16 -0.879394 -0.779346  0.189177  0.832956  1.071753 -0.072752 -0.505197
# 17  1.011782 -1.066249 -0.401398  0.124532 -0.079639  0.713658  0.137254
# 18 -0.132323  1.457883  0.730342  0.301882  0.641183 -0.036608 -0.533006
# 19 -0.313666  0.400687 -0.819460  0.580139  0.537071 -0.698757 -0.314959
#
# [20 rows x 5660 columns]

# %%
X_test = test_df.iloc[:,2:] #best features according to PCA 
y_test = test_df.iloc[:,0] #numerical labels

# %%
y_pred = cv_params.best_estimator_.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

# %%
print("Accuracy test set: ", accuracy)
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

class_names = ['Blended', 'Denim', 'Polyester', 'Cotton', 'Wool']

# Plot confusion matrix
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the figure size as necessary
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

# To improve readability, you might not want to display labels for all classes if there are many of them
disp.plot(include_values=True, cmap='viridis', ax=ax, xticks_rotation='vertical', values_format = 'd')
# disp.plot(cmap='viridis', ax=ax, xticks_rotation='vertical')

plt.show()
# Out:
# Accuracy test set:  0.3948879954049397
